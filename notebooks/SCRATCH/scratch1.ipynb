# %%
from __future__ import print_function, division
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import h5py
# %matplotlib inline

# %% [markdown]
# # Train, Test and Validation data - limited angle

# %%
f = h5py.File("../../src/data/test/1.hdf5", "r")
fig,(ax1,ax2) = plt.subplots(nrows=1,ncols=2)
ax1.imshow(f['lim'])
ax2.imshow(f['full'])

f = h5py.File("../../src/data/train/23.hdf5", "r")
fig,(ax1,ax2) = plt.subplots(nrows=1,ncols=2)
ax1.imshow(f['lim'])
ax2.imshow(f['full'])

f = h5py.File("../../src/data/val/45.hdf5", "r")
fig,(ax1,ax2) = plt.subplots(nrows=1,ncols=2)
ax1.imshow(f['lim'])
ax2.imshow(f['full'])
